# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
import re 
import joblib
import string

# %%
fake=pd.read_csv('Fake (2).csv')
true=pd.read_csv('True (1).csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['class']=1
fake['class']=0

# %%
data=pd.concat([fake,true],axis=0)

# %%
data.sample(10)
# Out:
#                                                    title  \
# 20834  France's foreign minister worried by Trump's s...
# 5165    Trump Just Outed Himself As YUUUGE Liar After...
# 4027   U.S. House may vote within days on tighter Nor...
# 7675   Winning in court, losing on the ground: uncert...
# 4325   Trump considers trade order that could lead to...
# 7979   U.S. senator: 'Unlikely' Cuba ambassador will ...
# 7865   Father of U.S. war hero attacks Trump's commen...
# 6110    The Los Angeles Times Endorses Hillary Clinto...
# 18753  Fear of volcanic eruption on Bali forces nearl...
# 13847  TRUMP COMES OUT SWINGING: New Ad Features One ...
#
#                                                     text       subject  \
# 20834  PARIS (Reuters) - France s foreign minister sa...     worldnews
# 5165   Oh, Donald Trump. The pathological liar has st...          News
# 4027   WASHINGTON (Reuters) - The U.S. House of Repre...  politicsNews
# 7675   WASHINGTON (Reuters) - U.S. voting rights advo...  politicsNews
# 4325   WASHINGTON (Reuters) - U.S. President Donald T...  politicsNews
# 7979   WASHINGTON (Reuters) - The chairman of the U.S...  politicsNews
# 7865   WASHINGTON (Reuters) - Khizr Khan, the father ...  politicsNews
# 6110   As Politico reports an almost neck-and-neck ra...          News
# 18753  KARANGASEM, Indonesia (Reuters) - Nearly 135,0...     worldnews
# 13847  Bill s gonna wish his corrupt wife never ran f...      politics
#
#                       date  class
# 20834   September 6, 2017       1
# 5165        August 5, 2016      0
# 4027       April 27, 2017       1
# 7675     October 27, 2016       1
# 4325       April 10, 2017       1
# 7979   September 29, 2016       1
# 7865     October 11, 2016       1
# 6110          May 30, 2016      0
# 18753  September 28, 2017       1
# 13847         May 23, 2016      0

# %%
data=data.drop(["title","subject","date"],axis=1)

# %%
data.reset_index(inplace=True)

# %%
data.drop(['index'],axis=1,inplace=True)

# %%
data.sample(3)
# Out:
#                                                     text  class
# 261    The 2016 election cycle was rife with hilariou...      0
# 10609  Indiana State Police say shots were fired at a...      0
# 31812  WASHINGTON (Reuters) - Marco Rubio, who droppe...      1

# %%
def clean_text(text):
    text=text.lower();
    text=re.sub('\[,*?\]',"",text)
    text=re.sub("https?:://\S+|www\. \S+","",text)
    text=re.sub("<.*?>+","",text)
    text=re.sub("[%s]" % re.escape(string.punctuation),"",text)
    text=re.sub("\n","",text)
    text=re.sub("\w*\d\w*","",text)
    return text
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:4: SyntaxWarning: invalid escape sequence '\S'
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# <>:3: SyntaxWarning: invalid escape sequence '\['
# <>:4: SyntaxWarning: invalid escape sequence '\S'
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\veera pratap\AppData\Local\Temp\ipykernel_37156\2409681164.py:3: SyntaxWarning: invalid escape sequence '\['
#   text=re.sub('\[,*?\]',"",text)
# C:\Users\veera pratap\AppData\Local\Temp\ipykernel_37156\2409681164.py:4: SyntaxWarning: invalid escape sequence '\S'
#   text=re.sub("https?:://\S+|www\. \S+","",text)
# C:\Users\veera pratap\AppData\Local\Temp\ipykernel_37156\2409681164.py:8: SyntaxWarning: invalid escape sequence '\w'
#   text=re.sub("\w*\d\w*","",text)

# %%
data["text"] =data["text"].apply(clean_text)

# %%
x=data["text"]
y=data["class"]

xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
vectorizer=TfidfVectorizer()
xv_train=vectorizer.fit_transform(xtrain)
xv_test=vectorizer.transform(xtest)

# %%
lr=LogisticRegression()
lr.fit(xv_train,ytrain)
# Out:
# LogisticRegression()

# %%
 prediction=lr.predict(xv_test)
 lr.score(xv_test,ytest)
# Out:
# 0.986369710467706

# %%
print(classification_report(ytest,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5895
#            1       0.98      0.99      0.99      5330
#
#     accuracy                           0.99     11225
#    macro avg       0.99      0.99      0.99     11225
# weighted avg       0.99      0.99      0.99     11225

# %%
joblib.dump(vectorizer,"vectorizer.jb")
joblib.dump(lr,"lr_model.jb")
# Out:
# ['lr_model.jb']
